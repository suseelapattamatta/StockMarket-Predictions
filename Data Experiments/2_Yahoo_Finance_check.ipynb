# %%
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# In C:\Users\sriku\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\sriku\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\sriku\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\sriku\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# ## yahoo finance DJIA data for 1st dataset

# %%
yahoo_djia = pd.read_csv("../Datasets/yahoo-finance/DJI.csv",parse_dates=[0],index_col=0).sort_index()
pd.concat((yahoo_djia.head(3),yahoo_djia.tail(2)))
# Out:
#                     Open          High           Low         Close  \
# Date
# 2006-01-03  10718.299805  10862.780273  10684.450195  10847.410156
# 2006-01-04  10843.969727  10892.639648  10833.900391  10880.150391
# 2006-01-05  10880.389648  10908.250000  10843.650391  10882.150391
# 2016-12-29  19835.460938  19878.439453  19788.939453  19819.779297
# 2016-12-30  19833.169922  19852.550781  19718.669922  19762.599609
#
#                Adj Close     Volume
# Date
# 2006-01-03  10847.410156  302950000
# 2006-01-04  10880.150391  271490000
# 2006-01-05  10882.150391  250910000
# 2016-12-29  19819.779297  172040000
# 2016-12-30  19762.599609  271910000

# %%
djia = pd.read_csv("../Datasets/djia/upload_DJIA_table.csv",parse_dates=[0],index_col=0).sort_index()
pd.concat((djia.head(3),djia.tail(2)))
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2008-08-08  11432.089844  11759.959961  11388.040039  11734.320312  212830000
# 2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609  183190000
# 2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727  173590000
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234  133030000
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141   82160000
#
#                Adj Close
# Date
# 2008-08-08  11734.320312
# 2008-08-11  11782.349609
# 2008-08-12  11642.469727
# 2016-06-30  17929.990234
# 2016-07-01  17949.369141

# %%
overlapping_yahoo_djia = yahoo_djia.loc['2008-08-08':'2016-07-01']
pd.concat((overlapping_yahoo_djia.head(3),overlapping_yahoo_djia.tail(2)))
# Out:
#                     Open          High           Low         Close  \
# Date
# 2008-08-08  11432.089844  11759.959961  11388.040039  11734.320313
# 2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
#
#                Adj Close     Volume
# Date
# 2008-08-08  11734.320313  212830000
# 2008-08-11  11782.349609  183190000
# 2008-08-12  11642.469727  173590000
# 2016-06-30  17929.990234  133030000
# 2016-07-01  17949.369141   82160000

# %%
date_range = ['2008-08-08','2008-09-30']
series = djia.Close.loc[date_range[0]:date_range[1]]
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 3))

# Add x-axis and y-axis
ax.bar(series.index.values,
       series,
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

plt.show()
# Out:
# C:\Users\sriku\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# From Yahoo

# %%
date_range = ['2008-08-08','2008-09-30']
series = yahoo_djia.Close.loc[date_range[0]:date_range[1]]
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 3))

# Add x-axis and y-axis
ax.bar(series.index.values,
       series,
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

plt.show()

# %% [markdown]
# ## yahoo finance Apple data for 2nd dataset

# %%
yahoo_apple = pd.read_csv("../Datasets/yahoo-finance/AAPL.csv",parse_dates=[0],index_col=0).sort_index()
pd.concat((yahoo_apple.head(3),yahoo_apple.tail(2)))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-01-03   10.340000   10.678572   10.321428   10.678572    9.244411
# 2006-01-04   10.732857   10.854285   10.642858   10.710000    9.271619
# 2006-01-05   10.690000   10.700000   10.535714   10.625714    9.198654
# 2016-12-29  116.449997  117.110001  116.400002  116.730003  110.943588
# 2016-12-30  116.650002  117.199997  115.430000  115.820000  110.078697
#
#                Volume
# Date
# 2006-01-03  201808600
# 2006-01-04  154900900
# 2006-01-05  112355600
# 2016-12-29   15039500
# 2016-12-30   30586300

# %%
apple = pd.read_csv("../Datasets/apple-microsoft/AppleFinalData.csv",parse_dates=[0],index_col=0).sort_index()
pd.concat((apple.head(3),apple.tail(2)))
# Out:
#                 Open    High       Low   Close  Adj Close  compound    neg  \
# Date
# 2006-12-01   13.1143   13.19   12.8714   91.32    13.0457    0.7707  0.032
# 2006-12-04   13.1257   13.15   12.9286   91.12    13.0171    0.8720  0.011
# 2006-12-05   13.0929   13.19   12.9814   91.27    13.0386    0.0000  0.000
# 2016-11-29  110.7800  112.03  110.0700  111.46   111.4600    0.0000  0.000
# 2016-11-30  111.6000  112.20  110.2700  110.52   110.5200    0.0000  0.000
#
#               neu    pos
# Date
# 2006-12-01  0.905  0.063
# 2006-12-04  0.904  0.085
# 2006-12-05  0.000  0.000
# 2016-11-29  0.000  0.000
# 2016-11-30  0.000  0.000

# %%
overlapping_yahoo_apple = yahoo_apple.loc['2006-12-01':'2016-11-30']
pd.concat((overlapping_yahoo_apple.head(3),overlapping_yahoo_apple.tail(2)))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-12-01   13.114285   13.190000   12.871428   13.045714   11.293642
# 2006-12-04   13.125714   13.150000   12.928572   13.017143   11.268908
# 2006-12-05   13.092857   13.190000   12.981428   13.038571   11.287459
# 2016-11-29  110.779999  112.029999  110.070000  111.459999  105.934830
# 2016-11-30  111.599998  112.199997  110.269997  110.519997  105.041428
#
#                Volume
# Date
# 2006-12-01  198769900
# 2006-12-04  177384200
# 2006-12-05  165709600
# 2016-11-29   28528800
# 2016-11-30   36162300

# %%
date_range = ['2008-08-08','2008-09-30']
series = apple.Close.loc[date_range[0]:date_range[1]]
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 3))

# Add x-axis and y-axis
ax.bar(series.index.values,
       series,
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

plt.show()

# %% [markdown]
# From Yahoo

# %%
date_range = ['2008-08-08','2008-09-30']
series = yahoo_apple.Close.loc[date_range[0]:date_range[1]]
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 3))

# Add x-axis and y-axis
ax.bar(series.index.values,
       series,
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

plt.show()

# %% [markdown]
# ## yahoo finance Microsoft data for 2nd dataset

# %%
yahoo_microsoft = pd.read_csv("../Datasets/yahoo-finance/MSFT.csv",parse_dates=[0],index_col=0).sort_index()
pd.concat((yahoo_microsoft.head(3),yahoo_microsoft.tail(2)))
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  26.250000  27.000000  26.100000  26.840000  19.602528  79973000
# 2006-01-04  26.770000  27.080000  26.770000  26.969999  19.697485  57975600
# 2006-01-05  26.959999  27.129999  26.910000  26.990000  19.712091  48245500
# 2016-12-29  62.860001  63.200001  62.730000  62.900002  59.270599  10250600
# 2016-12-30  62.959999  62.990002  62.029999  62.139999  58.554443  25579900

# %%
microsoft = pd.read_csv("../Datasets/apple-microsoft/MicrosoftFinalData.csv",parse_dates=[0],index_col=0).sort_index()
pd.concat((microsoft.head(3),microsoft.tail(2)))
# Out:
#              Open   High    Low  Close  Adj Close  compound    neg    neu  pos
# Date
# 2006-12-01  29.23  29.30  28.90  29.12      29.12    0.0000  0.000  0.000  0.0
# 2006-12-04  29.23  29.52  29.17  29.33      29.33   -0.7783  0.137  0.863  0.0
# 2006-12-05  29.36  29.40  29.03  29.13      29.13    0.0000  0.000  0.000  0.0
# 2016-11-29  60.65  61.41  60.52  61.09      61.09    0.0000  0.000  0.000  0.0
# 2016-11-30  60.86  61.18  60.22  60.26      60.26    0.0000  0.000  0.000  0.0

# %%
overlapping_yahoo_microsoft = yahoo_microsoft.loc['2006-12-01':'2016-11-30']
pd.concat((overlapping_yahoo_microsoft.head(3),overlapping_yahoo_microsoft.tail(2)))
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-12-01  29.230000  29.299999  28.900000  29.120001  21.575411  72257000
# 2006-12-04  29.230000  29.520000  29.170000  29.330000  21.731007  55123400
# 2006-12-05  29.360001  29.400000  29.030001  29.129999  21.582817  45606000
# 2016-11-29  60.650002  61.410000  60.520000  61.090000  57.565033  22366700
# 2016-11-30  60.860001  61.180000  60.220001  60.259998  56.782925  34655400

# %%
date_range = ['2008-08-08','2008-09-30']
series = microsoft.Close.loc[date_range[0]:date_range[1]]
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 3))

# Add x-axis and y-axis
ax.bar(series.index.values,
       series,
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

plt.show()

# %% [markdown]
# From Yahoo

# %%
date_range = ['2008-08-08','2008-09-30']
series = yahoo_microsoft.Close.loc[date_range[0]:date_range[1]]
# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 3))

# Add x-axis and y-axis
ax.bar(series.index.values,
       series,
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Precipitation (inches)",
       title="Daily Total Precipitation\nJune - Aug 2005 for Boulder Creek")

plt.show()
